# %% [markdown]
# # Intorduction
#
# This is very interesting dataset to analyze the situation of cacao based chocolates and their ratings

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
foc_df = pd.read_csv('flavors_of_cacao.csv')
foc_df.head()
# Out:
#     Company Specific_Bean_Origin_or_Bar_Name   REF  Review_Date  \
# 0  A. Morin                      Agua Grande  1876         2016
# 1  A. Morin                            Kpime  1676         2015
# 2  A. Morin                           Atsane  1676         2015
# 3  A. Morin                            Akata  1680         2015
# 4  A. Morin                           Quilla  1704         2015
#
#    Cocoa_Percent Company_Location  Rating Bean_Type Broad Bean_Origin
# 0           0.63           France    3.75       NaN          Sao Tome
# 1           0.70           France    2.75       NaN              Togo
# 2           0.70           France    3.00       NaN              Togo
# 3           0.70           France    3.50       NaN              Togo
# 4           0.70           France    3.50       NaN              Peru

# %% [markdown]
# # Data overview

# %%
foc_df.columns # Naudokite metodą .columns - jis parodo stulpelius
# Out:
# Index(['Company', 'Specific_Bean_Origin_or_Bar_Name', 'REF', 'Review_Date',
#        'Cocoa_Percent', 'Company_Location', 'Rating', 'Bean_Type',
#        'Broad Bean_Origin'],
#       dtype='object')

# %%
foc_df.head(10)
# Out:
#     Company Specific_Bean_Origin_or_Bar_Name   REF  Review_Date  \
# 0  A. Morin                      Agua Grande  1876         2016
# 1  A. Morin                            Kpime  1676         2015
# 2  A. Morin                           Atsane  1676         2015
# 3  A. Morin                            Akata  1680         2015
# 4  A. Morin                           Quilla  1704         2015
# 5  A. Morin                         Carenero  1315         2014
# 6  A. Morin                             Cuba  1315         2014
# 7  A. Morin                     Sur del Lago  1315         2014
# 8  A. Morin                   Puerto Cabello  1319         2014
# 9  A. Morin                          Pablino  1319         2014
#
#    Cocoa_Percent Company_Location  Rating Bean_Type Broad Bean_Origin
# 0           0.63           France    3.75       NaN          Sao Tome
# 1           0.70           France    2.75       NaN              Togo
# ...

# %%
foc_df.describe()
# Out:
#                REF  Review_Date  Cocoa_Percent       Rating
# count  1795.000000  1795.000000    1795.000000  1795.000000
# mean   1035.904735  2012.325348       0.717003     3.185933
# std     552.886365     2.927210       0.063230     0.478062
# min       5.000000  2006.000000       0.420000     1.000000
# 25%     576.000000  2010.000000       0.700000     2.875000
# 50%    1069.000000  2013.000000       0.700000     3.250000
# 75%    1502.000000  2015.000000       0.750000     3.500000
# max    1952.000000  2017.000000       1.000000     5.000000

# %%
foc_df['Review_Date'].value_counts()
# Out:
# 2015    285
# 2014    247
# 2016    219
# 2012    195
# 2013    184
# 2011    165
# 2009    123
# 2010    111
# 2008     93
# 2007     77
# 2006     72
# 2017     24
# Name: Review_Date, dtype: int64

# %% [markdown]
# # Data analysis

# %%
#Average rating
foc_df['Rating'].mean()
# Out:
# 3.185933147632312

# %%
#Average rating by date
foc_df.groupby('Review_Date').mean()['Rating']
# Out:
# Review_Date
# 2006    3.125000
# 2007    3.162338
# 2008    2.994624
# 2009    3.073171
# 2010    3.148649
# 2011    3.256061
# 2012    3.178205
# 2013    3.197011
# 2014    3.189271
# 2015    3.246491
# 2016    3.226027
# 2017    3.312500
# Name: Rating, dtype: float64

# %%
#Cocoa percentage by country

foc_df.groupby('Company_Location').Cocoa_Percent.mean()
# Out:
# Company_Location
# Amsterdam            0.732500
# Argentina            0.733333
# Australia            0.702245
# Austria              0.720000
# Belgium              0.720250
# Bolivia              0.730000
# Brazil               0.698235
# Canada               0.723520
# Chile                0.700000
# Colombia             0.657391
# Costa Rica           0.720000
# Czech Republic       0.630000
# Denmark              0.698000
# Domincan Republic    0.670000
# Ecuador              0.723333
# Eucador              0.750000
# Fiji                 0.750000
# Finland              0.705000
# France               0.717628
# Germany              0.729429
# Ghana                0.800000
# Grenada              0.710000
# Guatemala            0.702000
# Honduras             0.750000
# Hungary              0.723182
# Iceland              0.686667
# India                0.610000
# Ireland              0.785000
# Israel               0.705556
# Italy                0.711905
# ...

# %%
foc_df['Bean_Type'].fillna('MISSING', inplace=True)
foc_df.head()
# Out:
#     Company Specific_Bean_Origin_or_Bar_Name   REF  Review_Date  \
# 0  A. Morin                      Agua Grande  1876         2016
# 1  A. Morin                            Kpime  1676         2015
# 2  A. Morin                           Atsane  1676         2015
# 3  A. Morin                            Akata  1680         2015
# 4  A. Morin                           Quilla  1704         2015
#
#    Cocoa_Percent Company_Location  Rating Bean_Type Broad Bean_Origin
# 0           0.63           France    3.75   MISSING          Sao Tome
# 1           0.70           France    2.75   MISSING              Togo
# 2           0.70           France    3.00   MISSING              Togo
# 3           0.70           France    3.50   MISSING              Togo
# 4           0.70           France    3.50   MISSING              Peru

# %%
# Top 5 companies by rating
foc_df.sort_values(by = 'Rating', ascending = False).head(5)
# Out:
#                      Company Specific_Bean_Origin_or_Bar_Name   REF  \
# 78                    Amedei                            Chuao   111
# 86                    Amedei                    Toscano Black    40
# 222                   Bonnat                            Kaori  1339
# 76                    Amedei                        Porcelana   111
# 1663  Tobago Estate (Pralus)               Roxborough, Tobago   895
#
#       Review_Date  Cocoa_Percent Company_Location  Rating  \
# 78           2007           0.70            Italy     5.0
# 86           2006           0.70            Italy     5.0
# 222          2014           0.75           France     4.0
# 76           2007           0.70            Italy     4.0
# 1663         2012           0.70           France     4.0
#
#                 Bean_Type Broad Bean_Origin
# 78             Trinitario         Venezuela
# 86                  Blend               NaN
# 222                   NaN            Brazil
# ...

# %%
# Bottom 5 companies by rating
foc_df.sort_values(by = 'Rating', ascending = False).tail(5)
# Out:
#                   Company Specific_Bean_Origin_or_Bar_Name  REF  Review_Date  \
# 245                Bonnat                      One Hundred   81         2006
# 437       Claudio Corallo                         Principe  252         2008
# 465    Cote d' Or (Kraft)               Sensations Intense   48         2006
# 326             Callebaut                           Baking  141         2007
# 1175  Neuhaus (Callebaut)                             Dark  135         2007
#
#       Cocoa_Percent Company_Location  Rating  Bean_Type    Broad Bean_Origin
# 245            1.00           France     1.5    MISSING                  NaN
# 437            1.00         Sao Tome     1.0  Forastero  Sao Tome & Principe
# 465            0.70          Belgium     1.0    MISSING                  NaN
# 326            0.70          Belgium     1.0    MISSING              Ecuador
# 1175           0.73          Belgium     1.0    MISSING                  NaN

# %%
# Companies in Lithuania
foc_df[foc_df['Company_Location']=='Lithuania']
# Out:
#      Company Specific_Bean_Origin_or_Bar_Name   REF  Review_Date  \
# 1162   Naive                Trinidad & Tobago  1046         2013
# 1163   Naive  Maranon Canyon, Fortunato No. 4  1133         2013
# 1164   Naive                          Grenada   867         2012
# 1165   Na�ve                        Nicaragua  1379         2014
# 1166   Na�ve                            Chuao  1399         2014
# 1167   Na�ve                          Barinas  1399         2014
#
#       Cocoa_Percent Company_Location  Rating             Bean_Type  \
# 1162           0.70        Lithuania    3.75               MISSING
# 1163           0.78        Lithuania    3.75  Forastero (Nacional)
# 1164           0.71        Lithuania    2.50            Trinitario
# 1165           0.70        Lithuania    3.25               Criollo
# 1166           0.75        Lithuania    2.75            Trinitario
# 1167           0.70        Lithuania    3.00               MISSING
#
#      Broad Bean_Origin
# ...

# %%
# Average ratings by country 
foc_df.groupby('Company_Location').mean()['Rating'].sort_values()
# Out:
# Company_Location
# India                2.500000
# Puerto Rico          2.625000
# South Africa         2.666667
# Mexico               2.687500
# Wales                2.750000
# Portugal             2.750000
# Martinique           2.750000
# Czech Republic       2.750000
# Ghana                2.750000
# Niacragua            2.750000
# Ireland              2.812500
# Grenada              2.833333
# Peru                 2.897059
# Sao Tome             2.937500
# St. Lucia            3.000000
# Nicaragua            3.000000
# Eucador              3.000000
# Ecuador              3.009259
# Sweden               3.050000
# U.K.                 3.054688
# Japan                3.088235
# Belgium              3.093750
# Costa Rica           3.138889
# Madagascar           3.147059
# U.S.A.               3.154123
# Lithuania            3.166667
# Colombia             3.173913
# Venezuela            3.175000
# Germany              3.178571
# New Zealand          3.191176
# ...

# %%
# Top 100 companies by rating
foc_df.sort_values(by = 'Rating', ascending = False).head(100)
# Out:
#                       Company               Specific_Bean_Origin_or_Bar_Name  \
# 78                     Amedei                                          Chuao
# 86                     Amedei                                  Toscano Black
# 222                    Bonnat                                          Kaori
# 76                     Amedei                                      Porcelana
# 1663   Tobago Estate (Pralus)                             Roxborough, Tobago
# ...                       ...                                            ...
# 918   L.A. Burdick (Felchlin)                                         Brazil
# 244                    Bonnat                                     Madagascar
# 1288         Pierre Marcolini                                        Cabosse
# 1322                   Pralus                        Claudio Corallo w/ nibs
# 865         Idilio (Felchlin)  Sur del Lago, Amiari Meridena, Zulia, w/ nibs
#
# ...

# %%
top100 = foc_df.sort_values(by = 'Rating', ascending = False).head(100)
top100['Company'].value_counts()
# Out:
# Soma                                    10
# Bonnat                                   8
# Amedei                                   6
# Valrhona                                 5
# Fresco                                   4
# Pierre Marcolini                         4
# Idilio (Felchlin)                        4
# Patric                                   3
# Domori                                   3
# Pacari                                   3
# Michel Cluizel                           3
# Pralus                                   3
# Cacao Sampaka                            3
# A. Morin                                 3
# Arete                                    3
# Amano                                    2
# Scharffen Berger                         2
# Matale                                   2
# Smooth Chocolator, The                   2
# Benoit Nihant                            2
# Artisan du Chocolat                      1
# Madecasse (Cinagra)                      1
# ...

# %% [markdown]
# # Data vizualization

# %%
# Average rating by year
rating_year = foc_df.groupby('Review_Date').mean()['Rating']
rating_year.plot()

# %%
rating_year = foc_df.groupby('Review_Date').mean()['Cocoa_Percent']
rating_year.plot()

# %%
# Correlations
foc_df['Rating'].corr(foc_df['Cocoa_Percent'])
# Out:
# -0.1650354223187782

# %% [markdown]
# # Conclucions
#
# There is no significant correlation between cocoa percent and rating.
#
# Chocolates from these countries have the best average rating:
# Philippines          3.500000
# Netherlands          3.500000
# Amsterdam            3.500000
# Chile                3.750000
#
# The company SOMA takes 10 places out of top 100 rating list
